# %%
#!/usr/bin/env python3
"""
CORRECTED BGP Feature Extraction Code
"""

import pandas as pd
import numpy as np
import datetime
from collections import defaultdict, Counter

# Configuration variables for Jupyter notebook
INPUT_FILE = "/home/smotaali/BGP_Traffic_Generation/RIPE/rrc04_20251116_updates.csv"
OUTPUT_FILE = "/home/smotaali/BGP_Traffic_Generation/results/rrc04_20251116_exctracted_1s_FIXED.csv"
WINDOW_SIZE = '1s'
LABEL_STRATEGY = 'majority'


def calculate_edit_distance(as_path1, as_path2):
    """Calculate edit distance between two AS paths"""
    if not as_path1 or not as_path2:
        return 0
    
    # Handle integer AS paths
    if isinstance(as_path1, int):
        as_path1 = [as_path1]
    if isinstance(as_path2, int):
        as_path2 = [as_path2]
    
    # Convert paths to lists if they are strings
    if isinstance(as_path1, str):
        as_path1 = as_path1.replace('{', '').replace('}', '')
        as_path1 = [int(as_num) for as_num in as_path1.split() if as_num.isdigit()]
    if isinstance(as_path2, str):
        as_path2 = as_path2.replace('{', '').replace('}', '')
        as_path2 = [int(as_num) for as_num in as_path2.split() if as_num.isdigit()]
    
    if not as_path1 or not as_path2:
        return 0
    
    m, n = len(as_path1), len(as_path2)
    dp = [[0] * (n + 1) for _ in range(m + 1)]
    
    for i in range(m + 1):
        dp[i][0] = i
    for j in range(n + 1):
        dp[0][j] = j
    
    for i in range(1, m + 1):
        for j in range(1, n + 1):
            if as_path1[i-1] == as_path2[j-1]:
                dp[i][j] = dp[i-1][j-1]
            else:
                dp[i][j] = 1 + min(dp[i-1][j], dp[i][j-1], dp[i-1][j-1])
    
    return dp[m][n]


def get_path_length(as_path):
    """Get the length of an AS path"""
    if pd.isnull(as_path) or as_path == '':
        return 0
    if isinstance(as_path, int):
        return 1
    if isinstance(as_path, str):
        as_path = as_path.replace('{', '').replace('}', '')
        return len([asn for asn in as_path.split() if asn.isdigit()])
    return 0


# =========================================================================
# MOVE THESE FUNCTIONS OUTSIDE extract_features_fixed
# =========================================================================
def attributes_are_same(row1, row2):
    """Compare BGP attributes between two announcements"""
    attrs_to_compare = ['AS_Path', 'Origin', 'Next_Hop', 'MED', 'Local_Pref', 'Communities']
    
    for attr in attrs_to_compare:
        if attr in row1.index and attr in row2.index:
            val1 = row1[attr]
            val2 = row2[attr]
            
            if pd.isna(val1) and pd.isna(val2):
                continue
            if pd.isna(val1) or pd.isna(val2):
                return False
            if val1 != val2:
                return False
    
    return True


def calculate_nadas_and_flaps(df_window):
    """
    Calculate NADAS and FLAPS using only UPDATE packets within window.
    
    NADAS: Withdrawal → Announcement with DIFFERENT attributes
    FLAP:  Withdrawal → Announcement with SAME attributes
    """
    nadas_count = 0
    flap_count = 0
    
    withdrawal_types = ['W', 'WITHDRAW', 'WITHDRAW_MP_UNREACH_NLRI_AFI2']
    
    # Sort by timestamp
    df_sorted = df_window.sort_values('Time')
    
    # Track state per (prefix, peer)
    prefix_state = {}
    
    for _, row in df_sorted.iterrows():
        key = (row['Prefix'], row['Peer_IP'])
        
        if row['Entry_Type'] == 'A':
            if key in prefix_state and prefix_state[key]['withdrawn']:
                last_ann = prefix_state[key].get('last_ann')
                
                if last_ann is not None:
                    if attributes_are_same(last_ann, row):
                        flap_count += 1
                    else:
                        nadas_count += 1
                else:
                    nadas_count += 1
                
                prefix_state[key]['withdrawn'] = False
            
            if key not in prefix_state:
                prefix_state[key] = {}
            prefix_state[key]['last_ann'] = row
            prefix_state[key]['withdrawn'] = False
            
        elif row['Entry_Type'] in withdrawal_types:
            if key in prefix_state:
                prefix_state[key]['withdrawn'] = True
            else:
                prefix_state[key] = {'last_ann': None, 'withdrawn': True}
    
    return nadas_count, flap_count


def extract_features_fixed(df_window):
    """
    Extract BGP features with CORRECTED calculations
    """
    features = {}
    
    # Basic counts
    announcements = df_window[df_window['Entry_Type'] == 'A']
    withdrawal_types = ['W', 'WITHDRAW_MP_UNREACH_NLRI_AFI2']
    withdrawals = df_window[df_window['Entry_Type'].isin(withdrawal_types)]
    
    features['announcements'] = len(announcements)
    features['withdrawals'] = len(withdrawals)
    features['nlri_ann'] = announcements['Prefix'].nunique()

    # =========================================================================
    # DUPLICATES
    # =========================================================================
    if not announcements.empty:
        dup_cols = ['Peer_IP', 'Peer_ASN', 'Prefix', 'AS_Path', 'Origin', 'Next_Hop', 'MED', 'Local_Pref', 'Communities']
        dup_cols = [col for col in dup_cols if col in announcements.columns]
        announcement_counts = announcements.groupby(dup_cols).size()
        duplicates = sum(count - 1 for count in announcement_counts if count > 1)
        features['dups'] = duplicates
    else:
        features['dups'] = 0
    
    # =========================================================================
    # ORIGIN ATTRIBUTES
    # =========================================================================
    if not announcements.empty and 'Origin' in announcements.columns:
        origin_counts = announcements['Origin'].value_counts()
        features['origin_0'] = origin_counts.get('IGP', 0)
        features['origin_2'] = origin_counts.get('INCOMPLETE', 0)
        
        unique_prefix_origins = announcements.groupby('Prefix')['Origin'].nunique()
        features['origin_changes'] = (unique_prefix_origins > 1).sum()
    else:
        features['origin_0'] = 0
        features['origin_2'] = 0
        features['origin_changes'] = 0
    
    # =========================================================================
    # IMPLICIT WITHDRAWALS
    # =========================================================================
    imp_wd_count = 0
    imp_wd_spath_count = 0
    imp_wd_dpath_count = 0

    edit_distances = []
    edit_distance_dict = defaultdict(list)

    attrs_to_compare = ['AS_Path', 'Origin', 'Next_Hop', 'MED', 'Local_Pref', 'Communities']

    if not announcements.empty:
        available_attrs = [col for col in attrs_to_compare if col in announcements.columns]
    
        for (prefix, peer), group in announcements.groupby(['Prefix', 'Peer_IP']):
            if len(group) >= 2:
                sorted_group = group.sort_values('Timestamp')
                prev_row = None
            
                for _, row in sorted_group.iterrows():
                    if prev_row is not None:
                        attributes_changed = False
                        as_path_changed = False
                    
                        for attr in available_attrs:
                            prev_val = prev_row[attr] if attr in prev_row.index else None
                            curr_val = row[attr] if attr in row.index else None
                        
                            prev_is_nan = pd.isna(prev_val)
                            curr_is_nan = pd.isna(curr_val)
                        
                            if prev_is_nan and curr_is_nan:
                                continue
                            if prev_is_nan or curr_is_nan:
                                attributes_changed = True
                                if attr == 'AS_Path':
                                    as_path_changed = True
                            elif prev_val != curr_val:
                                attributes_changed = True
                                if attr == 'AS_Path':
                                    as_path_changed = True
                    
                        if attributes_changed:
                            imp_wd_count += 1
                        
                            if as_path_changed:
                                imp_wd_dpath_count += 1
                            
                                prev_path = prev_row.get('AS_Path', '')
                                curr_path = row.get('AS_Path', '')
                                if prev_path and curr_path:
                                    dist = calculate_edit_distance(prev_path, curr_path)
                                    edit_distances.append(dist)
                                    edit_distance_dict[prefix].append(dist)
                            else:
                                imp_wd_spath_count += 1
                
                    prev_row = row

    features['imp_wd'] = imp_wd_count
    features['imp_wd_spath'] = imp_wd_spath_count
    features['imp_wd_dpath'] = imp_wd_dpath_count

    # =========================================================================
    # AS PATH METRICS
    # =========================================================================
    if not announcements.empty and 'AS_Path' in announcements.columns:
        valid_as_paths = announcements[announcements['AS_Path'].notna() & (announcements['AS_Path'] != '')]
        
        if not valid_as_paths.empty:
            as_path_lengths = valid_as_paths['AS_Path'].apply(get_path_length)
            features['as_path_max'] = as_path_lengths.max() if not as_path_lengths.empty else 0
            
            unique_paths_per_prefix = valid_as_paths.groupby('Prefix')['AS_Path'].nunique()
            features['unique_as_path_max'] = unique_paths_per_prefix.max() if not unique_paths_per_prefix.empty else 0
        else:
            features['as_path_max'] = 0
            features['unique_as_path_max'] = 0
    else:
        features['as_path_max'] = 0
        features['unique_as_path_max'] = 0
    
    # =========================================================================
    # EDIT DISTANCE FEATURES
    # =========================================================================
    if edit_distances:
        features['edit_distance_avg'] = np.mean(edit_distances)
        features['edit_distance_max'] = max(edit_distances)
        
        edit_dist_counter = Counter(edit_distances)
        for i in range(7):
            features[f'edit_distance_dict_{i}'] = edit_dist_counter.get(i, 0)
        
        unique_edit_dists = {}
        for prefix, dists in edit_distance_dict.items():
            unique_dists = set(dists)
            for dist in unique_dists:
                unique_edit_dists[dist] = unique_edit_dists.get(dist, 0) + 1
        
        for i in range(2):
            features[f'edit_distance_unique_dict_{i}'] = unique_edit_dists.get(i, 0)
    else:
        features['edit_distance_avg'] = 0
        features['edit_distance_max'] = 0
        for i in range(7):
            features[f'edit_distance_dict_{i}'] = 0
        for i in range(2):
            features[f'edit_distance_unique_dict_{i}'] = 0
    
    # =========================================================================
    # RARE AS FEATURES
    # =========================================================================
    if not announcements.empty and 'AS_Path' in announcements.columns:
        all_asns = []
        
        for as_path in announcements['AS_Path']:
            if pd.isnull(as_path) or as_path == '':
                continue
            
            as_path_str = str(as_path)
            
            if as_path_str.isdigit():
                all_asns.append(as_path_str)
                continue
            
            as_path_str = as_path_str.replace('{', '').replace('}', '')
            path_asns = [asn for asn in as_path_str.split() if asn.isdigit()]
            all_asns.extend(path_asns)
        
        asn_counts = Counter(all_asns)
        rare_threshold = 3
        rare_asns = [asn for asn, count in asn_counts.items() if count < rare_threshold]
        
        features['number_rare_ases'] = len(rare_asns)
        features['rare_ases_avg'] = len(rare_asns) / len(all_asns) if all_asns else 0
    else:
        features['number_rare_ases'] = 0
        features['rare_ases_avg'] = 0
    
    # =========================================================================
    # NADAS AND FLAPS - NOW ACTUALLY CALLED!
    # =========================================================================
    nadas_count, flap_count = calculate_nadas_and_flaps(df_window)
    features['nadas'] = nadas_count
    features['flaps'] = flap_count
    
    # =========================================================================
    # LABEL
    # =========================================================================
    if 'Label' in df_window.columns:
        labels = df_window['Label'].value_counts()
        if not labels.empty:
            if LABEL_STRATEGY == 'majority':
                features['label'] = labels.idxmax()
            elif LABEL_STRATEGY == 'conservative':
                if any(label != 'normal' for label in labels.index):
                    abnormal_labels = [label for label in labels.index if label != 'normal']
                    features['label'] = abnormal_labels[0]
                else:
                    features['label'] = 'normal'
            elif LABEL_STRATEGY == 'weighted':
                total = labels.sum()
                abnormal_weight = sum(count for label, count in labels.items() if label != 'normal') / total
                if abnormal_weight > 0.4:
                    abnormal_labels = [label for label in labels.index if label != 'normal']
                    features['label'] = abnormal_labels[0] if abnormal_labels else 'normal'
                else:
                    features['label'] = 'normal'
        else:
            features['label'] = 'unknown'
    else:
        features['label'] = 'unknown'
    
    return features


def process_bgp_data():
    """Process BGP data file and extract features with specified time window"""
    print(f"Reading input file: {INPUT_FILE}")
    df = pd.read_csv(INPUT_FILE)
    
    df['Timestamp'] = pd.to_datetime(df['Time'])
    df = df.sort_values('Timestamp')
    
    start_time = df['Timestamp'].min()
    end_time = df['Timestamp'].max()
    
    print(f"Time range: {start_time} to {end_time}")
    
    df.set_index('Timestamp', inplace=True)
    
    all_features = []
    grouped = df.groupby(pd.Grouper(freq=WINDOW_SIZE))
    
    window_count = 0
    total_windows = len(grouped)
    
    for window_start, window_df in grouped:
        if not window_df.empty:
            window_df = window_df.reset_index()
            features = extract_features_fixed(window_df)
            
            if features:
                window_end = window_start + pd.Timedelta(WINDOW_SIZE)
                features['window_start'] = window_start
                features['window_end'] = window_end
                all_features.append(features)
                window_count += 1
                
                if window_count % 50 == 0:
                    print(f"Processed {window_count}/{total_windows} windows ({window_count/total_windows:.1%})...")
    
    print(f"Total windows processed: {window_count}")
    
    if all_features:
        features_df = pd.DataFrame(all_features)
        
        features_df.to_csv(OUTPUT_FILE, index=False)
        print(f"Features written to {OUTPUT_FILE}")
        
        # Print diagnostic
        print("\n" + "="*60)
        print("DIAGNOSTIC")
        print("="*60)
        print(f"Total withdrawals: {features_df['withdrawals'].sum()}")
        print(f"Total flaps: {features_df['flaps'].sum()}")
        print(f"Total nadas: {features_df['nadas'].sum()}")
        print(f"Total imp_wd: {features_df['imp_wd'].sum()}")
        print(f"Total imp_wd_spath: {features_df['imp_wd_spath'].sum()}")
        print(f"Total imp_wd_dpath: {features_df['imp_wd_dpath'].sum()}")
        print("="*60)
        
        return features_df
    else:
        print("No features extracted. Check input data.")
        return None


# Main execution
if __name__ == "__main__":
    features_df = process_bgp_data()
# Out:
# Reading input file: /home/smotaali/BGP_Traffic_Generation/RIPE/rrc04_20251116_updates.csv
# /tmp/ipykernel_597214/3030956130.py:363: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(INPUT_FILE)
# Time range: 2025-11-16 00:05:00 to 2025-11-17 00:04:59
# Processed 50/86400 windows (0.1%)...
# Processed 100/86400 windows (0.1%)...
# Processed 150/86400 windows (0.2%)...
# Processed 200/86400 windows (0.2%)...
# Processed 250/86400 windows (0.3%)...
# Processed 300/86400 windows (0.3%)...
# Processed 350/86400 windows (0.4%)...
# Processed 400/86400 windows (0.5%)...
# Processed 450/86400 windows (0.5%)...
# Processed 500/86400 windows (0.6%)...
# Processed 550/86400 windows (0.6%)...
# Processed 600/86400 windows (0.7%)...
# Processed 650/86400 windows (0.8%)...
# Processed 700/86400 windows (0.8%)...
# Processed 750/86400 windows (0.9%)...
# Processed 800/86400 windows (0.9%)...
# Processed 850/86400 windows (1.0%)...
# Processed 900/86400 windows (1.0%)...
# Processed 950/86400 windows (1.1%)...
# Processed 1000/86400 windows (1.2%)...
# Processed 1050/86400 windows (1.2%)...
# Processed 1100/86400 windows (1.3%)...
# Processed 1150/86400 windows (1.3%)...
# Processed 1200/86400 windows (1.4%)...
# Processed 1250/86400 windows (1.4%)...
# Processed 1300/86400 windows (1.5%)...
# Processed 1350/86400 windows (1.6%)...
# Processed 1400/86400 windows (1.6%)...
# Processed 1450/86400 windows (1.7%)...
# Processed 1500/86400 windows (1.7%)...
# Processed 1550/86400 windows (1.8%)...
# Processed 1600/86400 windows (1.9%)...
# Processed 1650/86400 windows (1.9%)...
# Processed 1700/86400 windows (2.0%)...
# Processed 1750/86400 windows (2.0%)...
# Processed 1800/86400 windows (2.1%)...
# Processed 1850/86400 windows (2.1%)...
# Processed 1900/86400 windows (2.2%)...
# Processed 1950/86400 windows (2.3%)...
# Processed 2000/86400 windows (2.3%)...
# Processed 2050/86400 windows (2.4%)...
# Processed 2100/86400 windows (2.4%)...
# Processed 2150/86400 windows (2.5%)...
# Processed 2200/86400 windows (2.5%)...
# Processed 2250/86400 windows (2.6%)...
# Processed 2300/86400 windows (2.7%)...
# Processed 2350/86400 windows (2.7%)...
# Processed 2400/86400 windows (2.8%)...
# Processed 2450/86400 windows (2.8%)...
# Processed 2500/86400 windows (2.9%)...
# Processed 2550/86400 windows (3.0%)...
# Processed 2600/86400 windows (3.0%)...
# Processed 2650/86400 windows (3.1%)...
# Processed 2700/86400 windows (3.1%)...
# Processed 2750/86400 windows (3.2%)...
# Processed 2800/86400 windows (3.2%)...
# Processed 2850/86400 windows (3.3%)...
# Processed 2900/86400 windows (3.4%)...
# Processed 2950/86400 windows (3.4%)...
# Processed 3000/86400 windows (3.5%)...
# Processed 3050/86400 windows (3.5%)...
# Processed 3100/86400 windows (3.6%)...
# Processed 3150/86400 windows (3.6%)...
# Processed 3200/86400 windows (3.7%)...
# Processed 3250/86400 windows (3.8%)...
# Processed 3300/86400 windows (3.8%)...
# Processed 3350/86400 windows (3.9%)...
# Processed 3400/86400 windows (3.9%)...
# Processed 3450/86400 windows (4.0%)...
# Processed 3500/86400 windows (4.1%)...
# Processed 3550/86400 windows (4.1%)...
# Processed 3600/86400 windows (4.2%)...
# Processed 3650/86400 windows (4.2%)...
# Processed 3700/86400 windows (4.3%)...
# Processed 3750/86400 windows (4.3%)...
# Processed 3800/86400 windows (4.4%)...
# Processed 3850/86400 windows (4.5%)...
# Processed 3900/86400 windows (4.5%)...
# Processed 3950/86400 windows (4.6%)...
# Processed 7700/86400 windows (8.9%)...
# Processed 7750/86400 windows (9.0%)...
# Processed 7800/86400 windows (9.0%)...
# Processed 7850/86400 windows (9.1%)...
# Processed 7900/86400 windows (9.1%)...
# Processed 7950/86400 windows (9.2%)...
# Processed 8000/86400 windows (9.3%)...
# Processed 8050/86400 windows (9.3%)...
# Processed 8100/86400 windows (9.4%)...
# Processed 8150/86400 windows (9.4%)...
# Processed 8200/86400 windows (9.5%)...
# Processed 8250/86400 windows (9.5%)...
# Processed 8300/86400 windows (9.6%)...
# Processed 8350/86400 windows (9.7%)...
# Processed 8400/86400 windows (9.7%)...
# Processed 8450/86400 windows (9.8%)...
# Processed 8500/86400 windows (9.8%)...
# Processed 8550/86400 windows (9.9%)...
# Processed 8600/86400 windows (10.0%)...
# Processed 8650/86400 windows (10.0%)...
# Processed 8700/86400 windows (10.1%)...
# Processed 8750/86400 windows (10.1%)...
# Processed 8800/86400 windows (10.2%)...
# Processed 8850/86400 windows (10.2%)...
# Processed 8900/86400 windows (10.3%)...
# Processed 8950/86400 windows (10.4%)...
# Processed 9000/86400 windows (10.4%)...
# Processed 9050/86400 windows (10.5%)...
# Processed 9100/86400 windows (10.5%)...
# Processed 9150/86400 windows (10.6%)...
# Processed 9200/86400 windows (10.6%)...
# Processed 9250/86400 windows (10.7%)...
# Processed 9300/86400 windows (10.8%)...
# Processed 9350/86400 windows (10.8%)...
# Processed 9400/86400 windows (10.9%)...
# Processed 9450/86400 windows (10.9%)...
# Processed 9500/86400 windows (11.0%)...
# Processed 9550/86400 windows (11.1%)...
# Processed 9600/86400 windows (11.1%)...
# Processed 9650/86400 windows (11.2%)...
# Processed 9700/86400 windows (11.2%)...
# Processed 9750/86400 windows (11.3%)...
# Processed 9800/86400 windows (11.3%)...
# Processed 9850/86400 windows (11.4%)...
# Processed 9900/86400 windows (11.5%)...
# Processed 9950/86400 windows (11.5%)...
# Processed 10000/86400 windows (11.6%)...
# Processed 10050/86400 windows (11.6%)...
# Processed 10100/86400 windows (11.7%)...
# Processed 10150/86400 windows (11.7%)...
# Processed 10200/86400 windows (11.8%)...
# Processed 10250/86400 windows (11.9%)...
# Processed 10300/86400 windows (11.9%)...
# Processed 10350/86400 windows (12.0%)...
# Processed 10400/86400 windows (12.0%)...
# Processed 10450/86400 windows (12.1%)...
# Processed 10500/86400 windows (12.2%)...
# Processed 10550/86400 windows (12.2%)...
# Processed 10600/86400 windows (12.3%)...
# Processed 10650/86400 windows (12.3%)...
# Processed 10700/86400 windows (12.4%)...
# Processed 10750/86400 windows (12.4%)...
# Processed 10800/86400 windows (12.5%)...
# Processed 10850/86400 windows (12.6%)...
# Processed 10900/86400 windows (12.6%)...
# Processed 10950/86400 windows (12.7%)...
# Processed 11000/86400 windows (12.7%)...
# Processed 11050/86400 windows (12.8%)...
# Processed 11100/86400 windows (12.8%)...
# Processed 11150/86400 windows (12.9%)...
# Processed 11200/86400 windows (13.0%)...
# Processed 11250/86400 windows (13.0%)...
# Processed 11300/86400 windows (13.1%)...
# Processed 11350/86400 windows (13.1%)...
# Processed 15100/86400 windows (17.5%)...
# Processed 15150/86400 windows (17.5%)...
# Processed 15200/86400 windows (17.6%)...
# Processed 15250/86400 windows (17.7%)...
# Processed 15300/86400 windows (17.7%)...
# Processed 15350/86400 windows (17.8%)...
# Processed 15400/86400 windows (17.8%)...
# Processed 15450/86400 windows (17.9%)...
# Processed 15500/86400 windows (17.9%)...
# Processed 15550/86400 windows (18.0%)...
# Processed 15600/86400 windows (18.1%)...
# Processed 15650/86400 windows (18.1%)...
# Processed 15700/86400 windows (18.2%)...
# Processed 15750/86400 windows (18.2%)...
# Processed 15800/86400 windows (18.3%)...
# Processed 15850/86400 windows (18.3%)...
# Processed 15900/86400 windows (18.4%)...
# Processed 15950/86400 windows (18.5%)...
# Processed 16000/86400 windows (18.5%)...
# Processed 16050/86400 windows (18.6%)...
# Processed 16100/86400 windows (18.6%)...
# Processed 16150/86400 windows (18.7%)...
# Processed 16200/86400 windows (18.8%)...
# Processed 16250/86400 windows (18.8%)...
# Processed 16300/86400 windows (18.9%)...
# Processed 16350/86400 windows (18.9%)...
# Processed 16400/86400 windows (19.0%)...
# Processed 16450/86400 windows (19.0%)...
# Processed 16500/86400 windows (19.1%)...
# Processed 16550/86400 windows (19.2%)...
# Processed 16600/86400 windows (19.2%)...
# Processed 16650/86400 windows (19.3%)...
# Processed 16700/86400 windows (19.3%)...
# Processed 16750/86400 windows (19.4%)...
# Processed 16800/86400 windows (19.4%)...
# Processed 16850/86400 windows (19.5%)...
# Processed 16900/86400 windows (19.6%)...
# Processed 16950/86400 windows (19.6%)...
# Processed 17000/86400 windows (19.7%)...
# Processed 17050/86400 windows (19.7%)...
# Processed 17100/86400 windows (19.8%)...
# Processed 17150/86400 windows (19.8%)...
# Processed 17200/86400 windows (19.9%)...
# Processed 17250/86400 windows (20.0%)...
# Processed 17300/86400 windows (20.0%)...
# Processed 17350/86400 windows (20.1%)...
# Processed 17400/86400 windows (20.1%)...
# Processed 17450/86400 windows (20.2%)...
# Processed 17500/86400 windows (20.3%)...
# Processed 17550/86400 windows (20.3%)...
# Processed 17600/86400 windows (20.4%)...
# Processed 17650/86400 windows (20.4%)...
# Processed 17700/86400 windows (20.5%)...
# Processed 17750/86400 windows (20.5%)...
# Processed 17800/86400 windows (20.6%)...
# Processed 17850/86400 windows (20.7%)...
# Processed 17900/86400 windows (20.7%)...
# Processed 17950/86400 windows (20.8%)...
# Processed 18000/86400 windows (20.8%)...
# Processed 18050/86400 windows (20.9%)...
# Processed 18100/86400 windows (20.9%)...
# Processed 18150/86400 windows (21.0%)...
# Processed 18200/86400 windows (21.1%)...
# Processed 18250/86400 windows (21.1%)...
# Processed 18300/86400 windows (21.2%)...
# Processed 18350/86400 windows (21.2%)...
# Processed 18400/86400 windows (21.3%)...
# Processed 18450/86400 windows (21.4%)...
# Processed 18500/86400 windows (21.4%)...
# Processed 18550/86400 windows (21.5%)...
# Processed 18600/86400 windows (21.5%)...
# Processed 18650/86400 windows (21.6%)...
# Processed 18700/86400 windows (21.6%)...
# Processed 18750/86400 windows (21.7%)...
# Processed 18800/86400 windows (21.8%)...
# Processed 18850/86400 windows (21.8%)...
# Processed 18900/86400 windows (21.9%)...
# Processed 18950/86400 windows (21.9%)...
# Processed 19000/86400 windows (22.0%)...
# Processed 19050/86400 windows (22.0%)...
# Processed 19100/86400 windows (22.1%)...
# Processed 19150/86400 windows (22.2%)...
# Processed 19200/86400 windows (22.2%)...
# Processed 19250/86400 windows (22.3%)...
# Processed 19300/86400 windows (22.3%)...
# Processed 19350/86400 windows (22.4%)...
# Processed 19400/86400 windows (22.5%)...
# Processed 19450/86400 windows (22.5%)...
# Processed 19500/86400 windows (22.6%)...
# Processed 19550/86400 windows (22.6%)...
# Processed 19600/86400 windows (22.7%)...
# Processed 19650/86400 windows (22.7%)...
# Processed 19700/86400 windows (22.8%)...
# Processed 19750/86400 windows (22.9%)...
# Processed 19800/86400 windows (22.9%)...
# Processed 19850/86400 windows (23.0%)...
# Processed 19900/86400 windows (23.0%)...
# Processed 19950/86400 windows (23.1%)...
# Processed 20000/86400 windows (23.1%)...
# Processed 20050/86400 windows (23.2%)...
# Processed 20100/86400 windows (23.3%)...
# Processed 20150/86400 windows (23.3%)...
# Processed 20200/86400 windows (23.4%)...
# Processed 20250/86400 windows (23.4%)...
# Processed 20300/86400 windows (23.5%)...
# Processed 20350/86400 windows (23.6%)...
# Processed 20400/86400 windows (23.6%)...
# Processed 20450/86400 windows (23.7%)...
# Processed 20500/86400 windows (23.7%)...
# Processed 20550/86400 windows (23.8%)...
# Processed 20600/86400 windows (23.8%)...
# Processed 20650/86400 windows (23.9%)...
# Processed 20700/86400 windows (24.0%)...
# Processed 20750/86400 windows (24.0%)...
# Processed 20800/86400 windows (24.1%)...
# Processed 20850/86400 windows (24.1%)...
# Processed 20900/86400 windows (24.2%)...
# Processed 20950/86400 windows (24.2%)...
# Processed 21000/86400 windows (24.3%)...
# Processed 21050/86400 windows (24.4%)...
# Processed 21100/86400 windows (24.4%)...
# Processed 21150/86400 windows (24.5%)...
# Processed 21200/86400 windows (24.5%)...
# Processed 21250/86400 windows (24.6%)...
# Processed 21300/86400 windows (24.7%)...
# Processed 21350/86400 windows (24.7%)...
# Processed 21400/86400 windows (24.8%)...
# Processed 21450/86400 windows (24.8%)...
# Processed 21500/86400 windows (24.9%)...
# Processed 21550/86400 windows (24.9%)...
# Processed 21600/86400 windows (25.0%)...
# Processed 21650/86400 windows (25.1%)...
# Processed 21700/86400 windows (25.1%)...
# Processed 21750/86400 windows (25.2%)...
# Processed 21800/86400 windows (25.2%)...
# Processed 21850/86400 windows (25.3%)...
# Processed 21900/86400 windows (25.3%)...
# Processed 21950/86400 windows (25.4%)...
# Processed 22000/86400 windows (25.5%)...
# Processed 22050/86400 windows (25.5%)...
# Processed 22100/86400 windows (25.6%)...
# Processed 22150/86400 windows (25.6%)...
# Processed 22200/86400 windows (25.7%)...
# Processed 22250/86400 windows (25.8%)...
# Processed 22300/86400 windows (25.8%)...
# Processed 22350/86400 windows (25.9%)...
# Processed 22400/86400 windows (25.9%)...
# Processed 22450/86400 windows (26.0%)...
# Processed 29900/86400 windows (34.6%)...
# Processed 29950/86400 windows (34.7%)...
# Processed 30000/86400 windows (34.7%)...
# Processed 30050/86400 windows (34.8%)...
# Processed 30100/86400 windows (34.8%)...
# Processed 30150/86400 windows (34.9%)...
# Processed 30200/86400 windows (35.0%)...
# Processed 30250/86400 windows (35.0%)...
# Processed 30300/86400 windows (35.1%)...
# Processed 30350/86400 windows (35.1%)...
# Processed 30400/86400 windows (35.2%)...
# Processed 30450/86400 windows (35.2%)...
# Processed 30500/86400 windows (35.3%)...
# Processed 30550/86400 windows (35.4%)...
# Processed 30600/86400 windows (35.4%)...
# Processed 30650/86400 windows (35.5%)...
# Processed 30700/86400 windows (35.5%)...
# Processed 30750/86400 windows (35.6%)...
# Processed 30800/86400 windows (35.6%)...
# Processed 30850/86400 windows (35.7%)...
# Processed 30900/86400 windows (35.8%)...
# Processed 30950/86400 windows (35.8%)...
# Processed 31000/86400 windows (35.9%)...
# Processed 31050/86400 windows (35.9%)...
# Processed 31100/86400 windows (36.0%)...
# Processed 31150/86400 windows (36.1%)...
# Processed 31200/86400 windows (36.1%)...
# Processed 31250/86400 windows (36.2%)...
# Processed 31300/86400 windows (36.2%)...
# Processed 31350/86400 windows (36.3%)...
# Processed 31400/86400 windows (36.3%)...
# Processed 31450/86400 windows (36.4%)...
# Processed 31500/86400 windows (36.5%)...
# Processed 31550/86400 windows (36.5%)...
# Processed 31600/86400 windows (36.6%)...
# Processed 31650/86400 windows (36.6%)...
# Processed 31700/86400 windows (36.7%)...
# Processed 31750/86400 windows (36.7%)...
# Processed 31800/86400 windows (36.8%)...
# Processed 31850/86400 windows (36.9%)...
# Processed 31900/86400 windows (36.9%)...
# Processed 31950/86400 windows (37.0%)...
# Processed 32000/86400 windows (37.0%)...
# Processed 32050/86400 windows (37.1%)...
# Processed 32100/86400 windows (37.2%)...
# Processed 32150/86400 windows (37.2%)...
# Processed 32200/86400 windows (37.3%)...
# Processed 32250/86400 windows (37.3%)...
# Processed 32300/86400 windows (37.4%)...
# Processed 32350/86400 windows (37.4%)...
# Processed 32400/86400 windows (37.5%)...
# Processed 32450/86400 windows (37.6%)...
# Processed 32500/86400 windows (37.6%)...
# Processed 32550/86400 windows (37.7%)...
# Processed 32600/86400 windows (37.7%)...
# Processed 32650/86400 windows (37.8%)...
# Processed 32700/86400 windows (37.8%)...
# Processed 32750/86400 windows (37.9%)...
# Processed 32800/86400 windows (38.0%)...
# Processed 32850/86400 windows (38.0%)...
# Processed 32900/86400 windows (38.1%)...
# Processed 32950/86400 windows (38.1%)...
# Processed 33000/86400 windows (38.2%)...
# Processed 33050/86400 windows (38.3%)...
# Processed 33100/86400 windows (38.3%)...
# Processed 33150/86400 windows (38.4%)...
# Processed 33200/86400 windows (38.4%)...
# Processed 33250/86400 windows (38.5%)...
# Processed 33300/86400 windows (38.5%)...
# Processed 33350/86400 windows (38.6%)...
# Processed 33400/86400 windows (38.7%)...
# Processed 33450/86400 windows (38.7%)...
# Processed 33500/86400 windows (38.8%)...
# Processed 33550/86400 windows (38.8%)...
# Processed 33600/86400 windows (38.9%)...
# Processed 33650/86400 windows (38.9%)...
# Processed 33700/86400 windows (39.0%)...
# Processed 33750/86400 windows (39.1%)...
# Processed 33800/86400 windows (39.1%)...
# Processed 33850/86400 windows (39.2%)...
# Processed 33900/86400 windows (39.2%)...
# Processed 33950/86400 windows (39.3%)...
# Processed 34000/86400 windows (39.4%)...
# Processed 34050/86400 windows (39.4%)...
# Processed 34100/86400 windows (39.5%)...
# Processed 34150/86400 windows (39.5%)...
# Processed 34200/86400 windows (39.6%)...
# Processed 34250/86400 windows (39.6%)...
# Processed 34300/86400 windows (39.7%)...
# Processed 34350/86400 windows (39.8%)...
# Processed 34400/86400 windows (39.8%)...
# Processed 34450/86400 windows (39.9%)...
# Processed 34500/86400 windows (39.9%)...
# Processed 34550/86400 windows (40.0%)...
# Processed 34600/86400 windows (40.0%)...
# Processed 34650/86400 windows (40.1%)...
# Processed 34700/86400 windows (40.2%)...
# Processed 34750/86400 windows (40.2%)...
# Processed 34800/86400 windows (40.3%)...
# Processed 34850/86400 windows (40.3%)...
# Processed 34900/86400 windows (40.4%)...
# Processed 34950/86400 windows (40.5%)...
# Processed 35000/86400 windows (40.5%)...
# Processed 35050/86400 windows (40.6%)...
# Processed 35100/86400 windows (40.6%)...
# Processed 35150/86400 windows (40.7%)...
# Processed 35200/86400 windows (40.7%)...
# Processed 35250/86400 windows (40.8%)...
# Processed 35300/86400 windows (40.9%)...
# Processed 35350/86400 windows (40.9%)...
# Processed 35400/86400 windows (41.0%)...
# Processed 35450/86400 windows (41.0%)...
# Processed 35500/86400 windows (41.1%)...
# Processed 35550/86400 windows (41.1%)...
# Processed 35600/86400 windows (41.2%)...
# Processed 35650/86400 windows (41.3%)...
# Processed 35700/86400 windows (41.3%)...
# Processed 35750/86400 windows (41.4%)...
# Processed 35800/86400 windows (41.4%)...
# Processed 35850/86400 windows (41.5%)...
# Processed 35900/86400 windows (41.6%)...
# Processed 35950/86400 windows (41.6%)...
# Processed 36000/86400 windows (41.7%)...
# Processed 36050/86400 windows (41.7%)...
# Processed 36100/86400 windows (41.8%)...
# Processed 36150/86400 windows (41.8%)...
# Processed 36200/86400 windows (41.9%)...
# Processed 36250/86400 windows (42.0%)...
# Processed 36300/86400 windows (42.0%)...
# Processed 36350/86400 windows (42.1%)...
# Processed 36400/86400 windows (42.1%)...
# Processed 36450/86400 windows (42.2%)...
# Processed 36500/86400 windows (42.2%)...
# Processed 36550/86400 windows (42.3%)...
# Processed 36600/86400 windows (42.4%)...
# Processed 36650/86400 windows (42.4%)...
# Processed 36700/86400 windows (42.5%)...
# Processed 36750/86400 windows (42.5%)...
# Processed 36800/86400 windows (42.6%)...
# Processed 36850/86400 windows (42.7%)...
# Processed 36900/86400 windows (42.7%)...
# Processed 36950/86400 windows (42.8%)...
# Processed 37000/86400 windows (42.8%)...
# Processed 37050/86400 windows (42.9%)...
# Processed 37100/86400 windows (42.9%)...
# Processed 37150/86400 windows (43.0%)...
# Processed 37200/86400 windows (43.1%)...
# Processed 37250/86400 windows (43.1%)...
# Processed 41000/86400 windows (47.5%)...
# Processed 41050/86400 windows (47.5%)...
# Processed 41100/86400 windows (47.6%)...
# Processed 41150/86400 windows (47.6%)...
# Processed 41200/86400 windows (47.7%)...
# Processed 41250/86400 windows (47.7%)...
# Processed 41300/86400 windows (47.8%)...
# Processed 41350/86400 windows (47.9%)...
# Processed 41400/86400 windows (47.9%)...
# Processed 41450/86400 windows (48.0%)...
# Processed 41500/86400 windows (48.0%)...
# Processed 41550/86400 windows (48.1%)...
# Processed 41600/86400 windows (48.1%)...
# Processed 41650/86400 windows (48.2%)...
# Processed 41700/86400 windows (48.3%)...
# Processed 41750/86400 windows (48.3%)...
# Processed 41800/86400 windows (48.4%)...
# Processed 41850/86400 windows (48.4%)...
# Processed 41900/86400 windows (48.5%)...
# Processed 41950/86400 windows (48.6%)...
# Processed 42000/86400 windows (48.6%)...
# Processed 42050/86400 windows (48.7%)...
# Processed 42100/86400 windows (48.7%)...
# Processed 42150/86400 windows (48.8%)...
# Processed 42200/86400 windows (48.8%)...
# Processed 42250/86400 windows (48.9%)...
# Processed 42300/86400 windows (49.0%)...
# Processed 42350/86400 windows (49.0%)...
# Processed 42400/86400 windows (49.1%)...
# Processed 42450/86400 windows (49.1%)...
# Processed 42500/86400 windows (49.2%)...
# Processed 42550/86400 windows (49.2%)...
# Processed 42600/86400 windows (49.3%)...
# Processed 42650/86400 windows (49.4%)...
# Processed 42700/86400 windows (49.4%)...
# Processed 42750/86400 windows (49.5%)...
# Processed 42800/86400 windows (49.5%)...
# Processed 42850/86400 windows (49.6%)...
# Processed 42900/86400 windows (49.7%)...
# Processed 42950/86400 windows (49.7%)...
# Processed 43000/86400 windows (49.8%)...
# Processed 43050/86400 windows (49.8%)...
# Processed 43100/86400 windows (49.9%)...
# Processed 43150/86400 windows (49.9%)...
# Processed 43200/86400 windows (50.0%)...
# Processed 43250/86400 windows (50.1%)...
# Processed 43300/86400 windows (50.1%)...
# Processed 43350/86400 windows (50.2%)...
# Processed 43400/86400 windows (50.2%)...
# Processed 43450/86400 windows (50.3%)...
# Processed 43500/86400 windows (50.3%)...
# Processed 43550/86400 windows (50.4%)...
# Processed 43600/86400 windows (50.5%)...
# Processed 43650/86400 windows (50.5%)...
# Processed 43700/86400 windows (50.6%)...
# Processed 43750/86400 windows (50.6%)...
# Processed 43800/86400 windows (50.7%)...
# Processed 43850/86400 windows (50.8%)...
# Processed 43900/86400 windows (50.8%)...
# Processed 43950/86400 windows (50.9%)...
# Processed 44000/86400 windows (50.9%)...
# Processed 44050/86400 windows (51.0%)...
# Processed 44100/86400 windows (51.0%)...
# Processed 44150/86400 windows (51.1%)...
# Processed 44200/86400 windows (51.2%)...
# Processed 44250/86400 windows (51.2%)...
# Processed 44300/86400 windows (51.3%)...
# Processed 44350/86400 windows (51.3%)...
# Processed 44400/86400 windows (51.4%)...
# Processed 44450/86400 windows (51.4%)...
# Processed 44500/86400 windows (51.5%)...
# Processed 44550/86400 windows (51.6%)...
# Processed 44600/86400 windows (51.6%)...
# Processed 44650/86400 windows (51.7%)...
# Processed 68350/86400 windows (79.1%)...
# Processed 68400/86400 windows (79.2%)...
# Processed 68450/86400 windows (79.2%)...
# Processed 68500/86400 windows (79.3%)...
# Processed 68550/86400 windows (79.3%)...
# Processed 68600/86400 windows (79.4%)...
# Processed 68650/86400 windows (79.5%)...
# Processed 68700/86400 windows (79.5%)...
# Processed 68750/86400 windows (79.6%)...
# Processed 68800/86400 windows (79.6%)...
# Processed 68850/86400 windows (79.7%)...
# Processed 68900/86400 windows (79.7%)...
# Processed 68950/86400 windows (79.8%)...
# Processed 69000/86400 windows (79.9%)...
# Processed 69050/86400 windows (79.9%)...
# Processed 69100/86400 windows (80.0%)...
# Processed 69150/86400 windows (80.0%)...
# Processed 69200/86400 windows (80.1%)...
# Processed 69250/86400 windows (80.2%)...
# Processed 69300/86400 windows (80.2%)...
# Processed 69350/86400 windows (80.3%)...
# Processed 69400/86400 windows (80.3%)...
# Processed 69450/86400 windows (80.4%)...
# Processed 69500/86400 windows (80.4%)...
# Processed 69550/86400 windows (80.5%)...
# Processed 69600/86400 windows (80.6%)...
# Processed 69650/86400 windows (80.6%)...
# Processed 69700/86400 windows (80.7%)...
# Processed 69750/86400 windows (80.7%)...
# Processed 69800/86400 windows (80.8%)...
# Processed 69850/86400 windows (80.8%)...
# Processed 69900/86400 windows (80.9%)...
# Processed 69950/86400 windows (81.0%)...
# Processed 70000/86400 windows (81.0%)...
# Processed 70050/86400 windows (81.1%)...
# Processed 70100/86400 windows (81.1%)...
# Processed 70150/86400 windows (81.2%)...
# Processed 70200/86400 windows (81.2%)...
# Processed 70250/86400 windows (81.3%)...
# Processed 70300/86400 windows (81.4%)...
# Processed 70350/86400 windows (81.4%)...
# Processed 70400/86400 windows (81.5%)...
# Processed 70450/86400 windows (81.5%)...
# Processed 70500/86400 windows (81.6%)...
# Processed 70550/86400 windows (81.7%)...
# Processed 70600/86400 windows (81.7%)...
# Processed 70650/86400 windows (81.8%)...
# Processed 70700/86400 windows (81.8%)...
# Processed 70750/86400 windows (81.9%)...
# Processed 70800/86400 windows (81.9%)...
# Processed 70850/86400 windows (82.0%)...
# Processed 70900/86400 windows (82.1%)...
# Processed 70950/86400 windows (82.1%)...
# Processed 71000/86400 windows (82.2%)...
# Processed 71050/86400 windows (82.2%)...
# Processed 71100/86400 windows (82.3%)...
# Processed 71150/86400 windows (82.3%)...
# Processed 71200/86400 windows (82.4%)...
# Processed 71250/86400 windows (82.5%)...
# Processed 71300/86400 windows (82.5%)...
# Processed 71350/86400 windows (82.6%)...
# Processed 71400/86400 windows (82.6%)...
# Processed 71450/86400 windows (82.7%)...
# Processed 71500/86400 windows (82.8%)...
# Processed 71550/86400 windows (82.8%)...
# Processed 71600/86400 windows (82.9%)...
# Processed 71650/86400 windows (82.9%)...
# Processed 71700/86400 windows (83.0%)...
# Processed 71750/86400 windows (83.0%)...
# Processed 71800/86400 windows (83.1%)...
# Processed 71850/86400 windows (83.2%)...
# Processed 71900/86400 windows (83.2%)...
# Processed 71950/86400 windows (83.3%)...
# Processed 72000/86400 windows (83.3%)...
# Processed 79450/86400 windows (92.0%)...
# Processed 79500/86400 windows (92.0%)...
# Processed 79550/86400 windows (92.1%)...
# Processed 79600/86400 windows (92.1%)...
# Processed 79650/86400 windows (92.2%)...
# Processed 79700/86400 windows (92.2%)...
# Processed 79750/86400 windows (92.3%)...
# Processed 79800/86400 windows (92.4%)...
# Processed 79850/86400 windows (92.4%)...
# Processed 79900/86400 windows (92.5%)...
# Processed 79950/86400 windows (92.5%)...
# Processed 80000/86400 windows (92.6%)...
# Processed 80050/86400 windows (92.7%)...
# Processed 80100/86400 windows (92.7%)...
# Processed 80150/86400 windows (92.8%)...
# Processed 80200/86400 windows (92.8%)...
# Processed 80250/86400 windows (92.9%)...
# Processed 80300/86400 windows (92.9%)...
# Processed 80350/86400 windows (93.0%)...
# Processed 80400/86400 windows (93.1%)...
# Processed 80450/86400 windows (93.1%)...
# Processed 80500/86400 windows (93.2%)...
# Processed 80550/86400 windows (93.2%)...
# Processed 80600/86400 windows (93.3%)...
# Processed 80650/86400 windows (93.3%)...
# Processed 80700/86400 windows (93.4%)...
# Processed 80750/86400 windows (93.5%)...
# Processed 80800/86400 windows (93.5%)...
# Processed 80850/86400 windows (93.6%)...
# Processed 80900/86400 windows (93.6%)...
# Processed 80950/86400 windows (93.7%)...
# Processed 81000/86400 windows (93.8%)...
# Processed 81050/86400 windows (93.8%)...
# Processed 81100/86400 windows (93.9%)...
# Processed 81150/86400 windows (93.9%)...
# Processed 81200/86400 windows (94.0%)...
# Processed 81250/86400 windows (94.0%)...
# Processed 81300/86400 windows (94.1%)...
# Processed 81350/86400 windows (94.2%)...
# Processed 81400/86400 windows (94.2%)...
# Processed 81450/86400 windows (94.3%)...
# Processed 81500/86400 windows (94.3%)...
# Processed 81550/86400 windows (94.4%)...
# Processed 81600/86400 windows (94.4%)...
# Processed 81650/86400 windows (94.5%)...
# Processed 81700/86400 windows (94.6%)...
# Processed 81750/86400 windows (94.6%)...
# Processed 81800/86400 windows (94.7%)...
# Processed 81850/86400 windows (94.7%)...
# Processed 81900/86400 windows (94.8%)...
# Processed 81950/86400 windows (94.8%)...
# Processed 82000/86400 windows (94.9%)...
# Processed 82050/86400 windows (95.0%)...
# Processed 82100/86400 windows (95.0%)...
# Processed 82150/86400 windows (95.1%)...
# Processed 82200/86400 windows (95.1%)...
# Processed 82250/86400 windows (95.2%)...
# Processed 82300/86400 windows (95.3%)...
# Processed 82350/86400 windows (95.3%)...
# Processed 82400/86400 windows (95.4%)...
# Processed 82450/86400 windows (95.4%)...
# Processed 82500/86400 windows (95.5%)...
# Processed 82550/86400 windows (95.5%)...
# Processed 82600/86400 windows (95.6%)...
# Processed 82650/86400 windows (95.7%)...
# Processed 82700/86400 windows (95.7%)...
# Processed 82750/86400 windows (95.8%)...
# Processed 82800/86400 windows (95.8%)...
# Processed 82850/86400 windows (95.9%)...
# Processed 82900/86400 windows (95.9%)...
# Processed 82950/86400 windows (96.0%)...
# Processed 83000/86400 windows (96.1%)...
# Processed 83050/86400 windows (96.1%)...
# Processed 83100/86400 windows (96.2%)...
# Processed 83150/86400 windows (96.2%)...
# Processed 83200/86400 windows (96.3%)...
# Processed 83250/86400 windows (96.4%)...
# Processed 83300/86400 windows (96.4%)...
# Processed 83350/86400 windows (96.5%)...
# Processed 83400/86400 windows (96.5%)...
# Processed 83450/86400 windows (96.6%)...
# Processed 83500/86400 windows (96.6%)...
# Processed 83550/86400 windows (96.7%)...
# Processed 83600/86400 windows (96.8%)...
# Processed 83650/86400 windows (96.8%)...
# Processed 83700/86400 windows (96.9%)...
# Processed 83750/86400 windows (96.9%)...
# Processed 83800/86400 windows (97.0%)...
# Processed 83850/86400 windows (97.0%)...
# Processed 83900/86400 windows (97.1%)...
# Processed 83950/86400 windows (97.2%)...
# Processed 84000/86400 windows (97.2%)...
# Processed 84050/86400 windows (97.3%)...
# Processed 84100/86400 windows (97.3%)...
# Processed 84150/86400 windows (97.4%)...
# Processed 84200/86400 windows (97.5%)...
# Processed 84250/86400 windows (97.5%)...
# Processed 84300/86400 windows (97.6%)...
# Processed 84350/86400 windows (97.6%)...
# Processed 84400/86400 windows (97.7%)...
# Processed 84450/86400 windows (97.7%)...
# Processed 84500/86400 windows (97.8%)...
# Processed 84550/86400 windows (97.9%)...
# Processed 84600/86400 windows (97.9%)...
# Processed 84650/86400 windows (98.0%)...
# Processed 84700/86400 windows (98.0%)...
# Processed 84750/86400 windows (98.1%)...
# Processed 84800/86400 windows (98.1%)...
# Processed 84850/86400 windows (98.2%)...
# Processed 84900/86400 windows (98.3%)...
# Processed 84950/86400 windows (98.3%)...
# Processed 85000/86400 windows (98.4%)...
# Processed 85050/86400 windows (98.4%)...
# Processed 85100/86400 windows (98.5%)...
# Processed 85150/86400 windows (98.6%)...
# Processed 85200/86400 windows (98.6%)...
# Processed 85250/86400 windows (98.7%)...
# Processed 85300/86400 windows (98.7%)...
# Processed 85350/86400 windows (98.8%)...
# Processed 85400/86400 windows (98.8%)...
# Processed 85450/86400 windows (98.9%)...
# Processed 85500/86400 windows (99.0%)...
# Processed 85550/86400 windows (99.0%)...
# Processed 85600/86400 windows (99.1%)...
# Processed 85650/86400 windows (99.1%)...
# Processed 85700/86400 windows (99.2%)...
# Processed 85750/86400 windows (99.2%)...
# Processed 85800/86400 windows (99.3%)...
# Processed 85850/86400 windows (99.4%)...
# Processed 85900/86400 windows (99.4%)...
# Processed 85950/86400 windows (99.5%)...
# Processed 86000/86400 windows (99.5%)...
# Processed 86050/86400 windows (99.6%)...
# Processed 86100/86400 windows (99.7%)...
# Processed 86150/86400 windows (99.7%)...
# Processed 86200/86400 windows (99.8%)...
# Processed 86250/86400 windows (99.8%)...
# Processed 86300/86400 windows (99.9%)...
# Processed 86350/86400 windows (99.9%)...
# Total windows processed: 86387
# Features written to /home/smotaali/BGP_Traffic_Generation/results/rrc04_20251116_exctracted_1s_FIXED.csv
#
# ============================================================
# DIAGNOSTIC
# ============================================================
# Total withdrawals: 1354818
# Total flaps: 35820
# Total nadas: 250327
# Total imp_wd: 1093714
# Total imp_wd_spath: 236689
# Total imp_wd_dpath: 857025
# ============================================================
